# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
                 #Data Cleaning:
#Load the Dataset
#Inspect the Data
#Handle Missing Values
#Remove Unnecessary Columns
#Feature Engineering.

# %%
train_data=pd.read_csv("train (3).csv")
test_data=pd.read_csv("test (2).csv")

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
## check sizee
test_data.shape
# Out:
# (418, 11)

# %%
train_data.shape
# Out:
# (891, 12)

# %%
combined=pd.concat([train_data,test_data],ignore_index=True)
combined.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
combined.shape
# Out:
# (1309, 12)

# %%
count_column,count_row=combined.shape

# %%
print("row",count_row)
print("coulmn",count_column)
# Out:
# row 12
# coulmn 1309

# %%
combined.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
combined.describe(include="object")
# Out:
#                         Name   Sex    Ticket        Cabin Embarked
# count                   1309  1309      1309          295     1307
# unique                  1307     2       929          186        3
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S
# freq                       2   843        11            6      914

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
num_cols=combined.select_dtypes(include=np.number).columns
num_cols
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
cols=combined.select_dtypes(include="object").columns
cols
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
## CHECK THE MISSING VALUE IN DATA
combined.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
combined.isnull().sum()[combined.isnull().sum()!=0]
# Out:
# Survived     418
# Age          263
# Fare           1
# Cabin       1014
# Embarked       2
# dtype: int64

# %%
## AFTER THIS  I CAN FIND MISING VALUE IN SURVIVED ,AGE AND CABIN COLUMN SO  FILL ALL MISSING VALUES.

# %%
# TREATMENT OF MISSING VALUE
combined["Survived"].unique()
# Out:
# array([ 0.,  1., nan])

# %%
combined["Age"].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  , 22.5 ,
#        18.5 , 67.  , 76.  , 26.5 , 60.5 , 11.5 ,  0.33,  0.17, 38.5 ])

# %%
##FILLED FARE WITH MEDIAN

combined.loc[combined.Fare.isnull(),'Fare']=combined.Fare.median()

# %%
## SOME OTHER METHOD TO FILL FARE
# fare_data=data["Fare"].median()
#data["fare"].fillna(fare_data,inplace=True)

# %%
mode_embarked = df['Embarked'].mode()[0]
df['Embarked'].fillna(mode_embarked, inplace=True)

# %%
## FILLED EMBARKED WITH MODE

combined.loc[combined.Embarked.isnull(),"Embarked"]=combined.Embarked.mode()[0]

# %%
combined.isnull().sum()[combined.isnull().sum()!=0]
# Out:
# Survived     418
# Age          263
# Cabin       1014
# dtype: int64

# %%
combined[combined['Age'].isnull()]
# Out:
#       PassengerId  Survived  Pclass                             Name     Sex  \
# 5               6       0.0       3                 Moran, Mr. James    male
# 17             18       1.0       2     Williams, Mr. Charles Eugene    male
# 19             20       1.0       3          Masselmani, Mrs. Fatima  female
# 26             27       0.0       3          Emir, Mr. Farred Chehab    male
# 28             29       1.0       3    O'Dwyer, Miss. Ellen "Nellie"  female
# ...           ...       ...     ...                              ...     ...
# 1299         1300       NaN       3  Riordan, Miss. Johanna Hannah""  female
# 1301         1302       NaN       3           Naughton, Miss. Hannah  female
# 1304         1305       NaN       3               Spector, Mr. Woolf    male
# 1307         1308       NaN       3              Ware, Mr. Frederick    male
# 1308         1309       NaN       3         Peter, Master. Michael J    male
#
# ...

# %%
combined["Age"].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  , 22.5 ,
#        18.5 , 67.  , 76.  , 26.5 , 60.5 , 11.5 ,  0.33,  0.17, 38.5 ])

# %%
median_age=combined["Age"].median()
combined["Age"].fillna(median_age,inplace=True)

# %%
combined.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# dtype: int64

# %%
#Since the 'Survived' column represents whether a passenger survived or not (0 = did not survive, 1 = survived),
#missing values likely correspond to passengers from the test set where survival information is not provided. 
#Since this column is the target variable for predictive modeling, may not need to impute missing values. 
#Instead, you can drop rows with missing value.

# %%
# for treat cabin  create a new column.(feature enginering)
combined.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
combined["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
cabins=['C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
       'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
       'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
       'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
       'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
       'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
       'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
       'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
       'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
       'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
       'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
       'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
       'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
       'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
       'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
       'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
       'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
       'C148', 'B45', 'B36', 'A21', 'D34', 'A9', 'C31', 'B61', 'C53',
       'D43', 'C130', 'C132', 'C55 C57', 'C116', 'F', 'A29', 'C6', 'C28',
       'C51', 'C97', 'D22', 'B10', 'E45', 'E52', 'A11', 'B11', 'C80',
       'C89', 'F E46', 'B26', 'F E57', 'A18', 'E60', 'E39 E41',
       'B52 B54 B56', 'C39', 'B24', 'D40', 'D38', 'C105']

# %%
def cabin_labels(x):
    if x in cabins:
        return('Cabin_Avbl')
    else:
        return('Missing')

# %%
combined['Cabin_cat'] = combined.Cabin.apply(cabin_labels)

# %%
combined["Cabin_cat"].unique()
# Out:
# array(['Missing', 'Cabin_Avbl'], dtype=object)

# %%
# DROP UNWANTED COLUMNS

# %%
combined.drop(['PassengerId','Name','Cabin','Ticket'],axis=1,inplace=True)

# %%
combined.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked   Cabin_cat
# 0       0.0       3    male  22.0      1      0   7.2500        S     Missing
# 1       1.0       1  female  38.0      1      0  71.2833        C  Cabin_Avbl
# 2       1.0       3  female  26.0      0      0   7.9250        S     Missing
# 3       1.0       1  female  35.0      1      0  53.1000        S  Cabin_Avbl
# 4       0.0       3    male  35.0      0      0   8.0500        S     Missing

# %%
## after this move on eda (DATA ANALYSIS)

# %%
# UNIVARIATE ANALYSIS
num=combined.select_dtypes(include=np.number).columns
t=1
for i in num:
    plt.subplot(3,2,t)
    sns.distplot(combined[i])
    t+=1
plt.tight_layout()
plt.show()

# %%
# OBSERVATION
# we observe that high chance to no survived (0 indicate did not survived) and and less chance to survived.
#we observe in pclass highest density of class 3 and low is class 2 
## age is normnal distribution .
#sibsp ,parch,fare are right skew

# %%
t=1
for i in num:
    plt.subplot(3,2,t)
    sns.boxplot(x=combined[i])
    t+=1
plt.tight_layout()
plt.show()

# %%
# outlier in age ,sibsp,parch,fare column.
# if we remove outlier so use iqr method to cap it .

# %%
cat_cols=combined.select_dtypes(include="object").columns
cat_cols
# Out:
# Index(['Sex', 'Embarked', 'Cabin_cat'], dtype='object')

# %%
cat_cols=['Sex', 'Embarked', 'Cabin_cat',"Survived"]

# %%
t=1
for i in cat_cols:
    plt.subplot(2,2,t)
    sns.countplot(x=combined[i])
    t+=1
plt.tight_layout()
plt.show()

# %%
##  ACCCORDING TO THIS MALE LESS CHANCE TO SURVIVED.
# S EMBARKED ,MISSING CABIN ALSO LESS CHANCE TO  SURVIVED

# %%
## BIVARAITE ANALYSIS.
sns.countplot(x='Survived',hue='Sex',data=combined)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",hue="Embarked",data=combined)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
t=1
for i in cat_cols:
    plt.subplot(2,2,t)
    sns.barplot(x=combined[i],y=combined["Survived"])
    t+=1
plt.tight_layout()
plt.show()

# %%
sns.heatmap(combined.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(combined)

# %%
# THEN WE MOVE TO ENCODING CHANGES CATEGORICAL COLUMNS TO NUMERICAL COLUMNS .
# APPLY LABEL ENCODING
combined["Sex"].value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
 
combined['Sex']=combined['Sex'].map({"male":0,"female":1}).astype(int)

# %%
combined["Embarked"].value_counts()
# Out:
# S    916
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
combined["Embarked"]=combined["Embarked"].map({"S":0,"C":1,"Q":2}).astype(int)

# %%
combined["Cabin_cat"].value_counts()
# Out:
# Missing       1014
# Cabin_Avbl     295
# Name: Cabin_cat, dtype: int64

# %%
combined["Cabin_cat"]=combined["Cabin_cat"].map({"Missing":0,"Cabin_Avbl":1}).astype(int)

# %%
combined.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Cabin_cat
# 0       0.0       3    0  22.0      1      0   7.2500         0          0
# 1       1.0       1    1  38.0      1      0  71.2833         1          1
# 2       1.0       3    1  26.0      0      0   7.9250         0          0
# 3       1.0       1    1  35.0      1      0  53.1000         0          1
# 4       0.0       3    0  35.0      0      0   8.0500         0          0

# %%
sns.heatmap(combined.corr(),annot=True)
# Out:
# <Axes: >

# %%
combined.skew()
# Out:
# Survived     0.478523
# Pclass      -0.598647
# Sex          0.602189
# Age          0.540987
# SibSp        3.844220
# Parch        3.669078
# Fare         4.369510
# Embarked     1.408110
# Cabin_cat    1.316125
# dtype: float64

# %%
combined.corr()
# Out:
#            Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived   1.000000 -0.338481  0.543351 -0.064910 -0.035322  0.081629
# Pclass    -0.338481  1.000000 -0.124617 -0.377908  0.060832  0.018322
# Sex        0.543351 -0.124617  1.000000 -0.053663  0.109609  0.213125
# Age       -0.064910 -0.377908 -0.053663  1.000000 -0.189972 -0.125851
# SibSp     -0.035322  0.060832  0.109609 -0.189972  1.000000  0.373587
# Parch      0.081629  0.018322  0.213125 -0.125851  0.373587  1.000000
# Fare       0.257307 -0.558683  0.185681  0.178182  0.160349  0.221635
# Embarked   0.106811  0.038875  0.120423  0.018654 -0.073461 -0.095523
# Cabin_cat  0.316912 -0.713857  0.137396  0.281124 -0.009064  0.036806
#
#                Fare  Embarked  Cabin_cat
# Survived   0.257307  0.106811   0.316912
# Pclass    -0.558683  0.038875  -0.713857
# Sex        0.185681  0.120423   0.137396
# Age        0.178182  0.018654   0.281124
# SibSp      0.160349 -0.073461  -0.009064
# ...

# %%
## observation
# pclass is -ve impact of survived.
# Age ,SibSp is -ve impact of survived.
